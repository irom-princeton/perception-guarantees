# %%
import numpy as np

# %%
from pathlib import Path
import argparse
import pickle
import json
import numpy as np
import matplotlib.pyplot as plt
import IPython as ipy


from nav_sim.env.task_env import TaskEnv
from models.numcc.src.engine.engine import prepare_data_udf
from models.numcc.src.engine.engine_viz import generate_html_udf

import models.numcc.main_numcc
import models.numcc.util.misc as misc
from models.numcc.src.engine.engine_viz import run_viz_udf
from models.numcc.util.hypersim_utils import read_h5py, read_img
from models.numcc.util.hypersim_dataset import random_crop, get_camera_pos_file_name_from_frame_name, get_camera_orientation_file_name_from_frame_name, read_scale_from_frame_name

from models.numcc.src.fns import *
from models.numcc.src.model.nu_mcc import NUMCC
import timm.optim.optim_factory as optim_factory
from models.numcc.util.misc import NativeScalerWithGradNormCount as NativeScaler


import sys
sys.path.append('../utils')
sys.path.append('../datasets')
# Out:
# pybullet build time: May 20 2022 19:45:31
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       6 import matplotlib.pyplot as plt
#       7 import IPython as ipy
# ---> 10 from nav_sim.env.task_env import TaskEnv
#      11 from models.numcc.src.engine.engine import prepare_data_udf
#      12 from models.numcc.src.engine.engine_viz import generate_html_udf
#
# File ~/Projects/perception-guarantees/nav_sim/env/__init__.py:1
# ----> 1 from nav_sim.env.vanilla_env import VanillaEnv
#       4 env_dict = {
#       5     'vanilla': VanillaEnv,
#       6 }
#
# File ~/Projects/perception-guarantees/nav_sim/env/vanilla_env.py:17
#      13 import pickle
#      15 from nav_sim.util.misc import rgba2rgb
# ---> 17 [k1, k2, A, B, R, BRB] = pickle.load(open('planning/sp_var.pkl','rb'))
#      18 k3 = A[2,3]
#      19 k4 = A[3,2]
#
# ...
